# %% [markdown]
# ### __Descriptive Analysis__

# %%
# Visual Python: Data Analysis > Import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Visual Python: Data Analysis > File
vp_df = pd.read_csv('./BIDM_Dataset.csv')
vp_df.head()
# Out:
#    Unnamed: 0  city        date  Day Month Festival  season interval  aqi  \
# 0           0  Agra  2023-01-01  Sun   Jan        0  Winter       Q1  5.0
# 1           1  Agra  2023-01-01  Sun   Jan        0  Winter       Q2  5.0
# 2           2  Agra  2023-01-01  Sun   Jan        0  Winter       Q3  5.0
# 3           3  Agra  2023-01-01  Sun   Jan        0  Winter       Q4  5.0
# 4           4  Agra  2023-01-02  Mon   Jan        0  Winter       Q1  5.0
#
#             co  ...        so2       pm2_5        pm10        nh3   temp_avg  \
# 0  1186.055000  ...   7.628333  137.000000  157.860000   6.428333   9.747167
# 1   983.556667  ...  18.536667  115.993333  128.063333   7.420000  18.038832
# 2  1740.136667  ...  26.621667  174.200000  202.561667  30.651667  13.288834
# 3  1584.368333  ...   7.848333  197.413333  224.560000   7.810000   9.347167
# 4  2116.205000  ...  16.571667  286.403333  311.601667   9.818333  10.030500
#
# ...

# %%
# Visual Python: Data Analysis > Frame
#vp_df.drop(['Unnamed: 0'], axis=1, inplace=True)
#vp_df.head()

# %%
## Data Information

# %%
# Visual Python: Data Analysis > Data Info
vp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208240 entries, 0 to 208239
# Data columns (total 22 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   city              208240 non-null  object
#  1   date              208240 non-null  object
#  2   Day               208240 non-null  object
#  3   Month             208240 non-null  object
#  4   Festival          208240 non-null  object
#  5   season            208240 non-null  object
#  6   interval          208240 non-null  object
#  7   aqi               208240 non-null  float64
#  8   co                208240 non-null  float64
#  9   no                208240 non-null  float64
#  10  no2               208240 non-null  float64
#  11  o3                208240 non-null  float64
#  12  so2               208240 non-null  float64
#  13  pm2_5             208240 non-null  float64
#  14  pm10              208240 non-null  float64
# ...

# %%
# Visual Python: Data Analysis > Data Info
vp_df.describe()
# Out:
#                  aqi             co             no            no2  \
# count  208240.000000  208240.000000  208240.000000  208240.000000
# mean        3.336244     789.445819       2.960702      17.570348
# std         1.394070     867.159328      11.476529      42.502484
# min         1.000000      62.958333       0.000000   -1665.295000
# 25%         2.000000     328.781667       0.020000       5.476667
# 50%         3.333333     537.395000       0.221667      11.425000
# 75%         5.000000     931.261667       1.200000      23.248333
# max         5.166667   17499.288330     381.468333     319.421667
#
#                   o3            so2          pm2_5           pm10  \
# count  208240.000000  208240.000000  208240.000000  208240.000000
# mean       62.288693      16.229530      73.169352      90.866925
# std        54.335252      22.373348      92.886836     110.419952
# min     -1664.083333       0.030000       0.500000   -1648.093333
# ...

# %%
## Null Count of variables in the dataset

# %%
# Visual Python: Data Analysis > Data Info
pd.DataFrame({'Null Count': vp_df[['aqi','co','no','no2','o3','so2','pm2_5','pm10','nh3','temp_avg','humidity','pressure','wind_speed','cloud_cover','precipitation_mm']].isnull().sum(), 'Non-Null Count': vp_df[['aqi','co','no','no2','o3','so2','pm2_5','pm10','nh3','temp_avg','humidity','pressure','wind_speed','cloud_cover','precipitation_mm']].notnull().sum()})
# Out:
#                   Null Count  Non-Null Count
# aqi                        0          208240
# co                         0          208240
# no                         0          208240
# no2                        0          208240
# o3                         0          208240
# so2                        0          208240
# pm2_5                      0          208240
# pm10                       0          208240
# nh3                        0          208240
# temp_avg                   0          208240
# humidity                   0          208240
# pressure                   0          208240
# wind_speed                 0          208240
# cloud_cover                0          208240
# precipitation_mm           0          208240

# %%
## Descriptive Statistics of the dataset

# %%
# Visual Python: Data Analysis > Data Info
pd.DataFrame({'count': vp_df[['aqi','co','no','no2','o3','so2','pm2_5','pm10','nh3','temp_avg','humidity','pressure','wind_speed','cloud_cover','precipitation_mm']].count(),'min': vp_df[['aqi','co','no','no2','o3','so2','pm2_5','pm10','nh3','temp_avg','humidity','pressure','wind_speed','cloud_cover','precipitation_mm']].min(numeric_only=True),'max': vp_df[['aqi','co','no','no2','o3','so2','pm2_5','pm10','nh3','temp_avg','humidity','pressure','wind_speed','cloud_cover','precipitation_mm']].max(numeric_only=True),'sum': vp_df[['aqi','co','no','no2','o3','so2','pm2_5','pm10','nh3','temp_avg','humidity','pressure','wind_speed','cloud_cover','precipitation_mm']].sum(numeric_only=True),'mean': vp_df[['aqi','co','no','no2','o3','so2','pm2_5','pm10','nh3','temp_avg','humidity','pressure','wind_speed','cloud_cover','precipitation_mm']].mean(numeric_only=True),'median': vp_df[['aqi','co','no','no2','o3','so2','pm2_5','pm10','nh3','temp_avg','humidity','pressure','wind_speed','cloud_cover','precipitation_mm']].median(numeric_only=True),'var': vp_df[['aqi','co','no','no2','o3','so2','pm2_5','pm10','nh3','temp_avg','humidity','pressure','wind_speed','cloud_cover','precipitation_mm']].var(numeric_only=True),'std': vp_df[['aqi','co','no','no2','o3','so2','pm2_5','pm10','nh3','temp_avg','humidity','pressure','wind_speed','cloud_cover','precipitation_mm']].std(numeric_only=True),'skew': vp_df[['aqi','co','no','no2','o3','so2','pm2_5','pm10','nh3','temp_avg','humidity','pressure','wind_speed','cloud_cover','precipitation_mm']].skew(numeric_only=True),'kurtosis': vp_df[['aqi','co','no','no2','o3','so2','pm2_5','pm10','nh3','temp_avg','humidity','pressure','wind_speed','cloud_cover','precipitation_mm']].kurtosis(numeric_only=True)})
# Out:
#                    count          min           max           sum  \
# aqi               208240     1.000000      5.166667  6.947396e+05
# co                208240    62.958333  17499.288330  1.643942e+08
# no                208240     0.000000    381.468333  6.165367e+05
# no2               208240 -1665.295000    319.421667  3.658849e+06
# o3                208240 -1664.083333    610.828333  1.297100e+07
# so2               208240     0.030000    440.595000  3.379637e+06
# pm2_5             208240     0.500000   1568.670000  1.523679e+07
# pm10              208240 -1648.093333   1767.366667  1.892213e+07
# nh3               208240     0.000000    267.841667  2.264837e+06
# temp_avg          208240     2.137833     47.052334  5.395422e+06
# humidity          208240     3.371838    100.000000  1.383497e+07
# pressure          208240   981.700012   1026.166626  2.100779e+08
# wind_speed        208240     0.229508     44.707226  1.940542e+06
# ...

# %%
## Correlation for all pollution variables

# %%
# Visual Python: Data Analysis > Data Info
_corr = vp_df[['aqi','co','no','no2','o3','so2','pm2_5','pm10','nh3']].corr(numeric_only=True)
_corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_4af7d_row0_col0, #T_4af7d_row1_col1, #T_4af7d_row2_col2, #T_4af7d_row3_col3, #T_4af7d_row4_col4, #T_4af7d_row5_col5, #T_4af7d_row6_col6, #T_4af7d_row7_col7, #T_4af7d_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_4af7d_row0_col1, #T_4af7d_row1_col5 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_4af7d_row0_col2 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_4af7d_row0_col3 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_4af7d_row0_col4 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_4af7d_row0_col5, #T_4af7d_row3_col6, #T_4af7d_row3_col7 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_4af7d_row0_col6 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_4af7d_row0_col7 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_4af7d_row0_col8 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_4af7d_row1_col0, #T_4af7d_row2_col8 {
# ...

# %%
## Correlation for all weather variables

# %%
# Visual Python: Data Analysis > Data Info
_corr = vp_df[['temp_avg','humidity','pressure','wind_speed','cloud_cover','precipitation_mm']].corr(numeric_only=True)
_corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_2ad15_row0_col0, #T_2ad15_row1_col1, #T_2ad15_row2_col2, #T_2ad15_row3_col3, #T_2ad15_row4_col4, #T_2ad15_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_2ad15_row0_col1, #T_2ad15_row0_col2, #T_2ad15_row2_col0, #T_2ad15_row2_col3, #T_2ad15_row2_col4, #T_2ad15_row2_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_2ad15_row0_col3, #T_2ad15_row1_col5 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_2ad15_row0_col4 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_2ad15_row0_col5 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_2ad15_row1_col0 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_2ad15_row1_col2, #T_2ad15_row4_col3 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_2ad15_row1_col3 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_2ad15_row1_col4 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# ...

# %%
## Correlation for temp_average with all pollutants

# %%
# Visual Python: Data Analysis > Data Info
_corr = vp_df[['aqi','co','no','no2','o3','so2','pm2_5','pm10','nh3','temp_avg']].corr(numeric_only=True)
_corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_49914_row0_col0, #T_49914_row1_col1, #T_49914_row2_col2, #T_49914_row3_col3, #T_49914_row4_col4, #T_49914_row5_col5, #T_49914_row6_col6, #T_49914_row7_col7, #T_49914_row8_col8, #T_49914_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_49914_row0_col1 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_49914_row0_col2 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_49914_row0_col3 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_49914_row0_col4, #T_49914_row2_col3, #T_49914_row3_col5 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_49914_row0_col5 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_49914_row0_col6 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_49914_row0_col7 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_49914_row0_col8 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_49914_row0_col9 {
# ...
